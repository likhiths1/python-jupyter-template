# %% [markdown]
# ### Exercise 6: Histogram Customization

# %%
# TASK: Create a histogram for the following data: data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5].
# Customize the histogram with a title, labels for the x-axis, and a specific color for the bars.
import matplotlib.pyplot as plt
import numpy as np

# Data
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5]

# Error handling
if not data:
    raise ValueError("Error: Data list cannot be empty.")

# Create a histogram
plt.figure(figsize=(6, 4))
counts, bins, patches = plt.hist(data, bins=5, color='red', edgecolor='black', alpha=0.7)

# Add value labels on top of bars
for count, bin_edge in zip(counts, bins[:-1]):
    plt.text(bin_edge + 0.3, count, str(int(count)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Labeling the axes and the plot
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Added grid for better readability

# Show the plot
plt.show()
